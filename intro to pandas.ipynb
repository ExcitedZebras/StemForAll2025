# %%
import pandas as pd

# %%
titanic_train = pd.read_csv(r'C:\Users\Woochoel Shin\Pictures\Ezras stuff temporary\coding\Stemforall\titanic.csv')

# %%
titanic_train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
titanic_train["Age"].describe()
# Out:
# count    887.000000
# mean      29.471443
# std       14.121908
# min        0.420000
# 25%       20.250000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic_train['Age'].isnull().value_counts()
# Out:
# Age
# False    887
# Name: count, dtype: int64

# %%
titanic_train.sample(10, random_state=1)
# Out:
#      Survived  Pclass                                         Name     Sex  \
# 522         0       3                            Mr. James Farrell    male
# 314         1       2           Mrs. Sinai (Miriam Sternin) Kantor  female
# 768         0       2                             Mrs. (Mary) Mack  female
# 320         1       2                     Miss. Hilda Mary Slayter  female
# 809         0       3            Miss. Ebba Iris Alfrida Andersson  female
# 3           1       1  Mrs. Jacques Heath (Lily May Peel) Futrelle  female
# 472         0       1                   Mr. George Quincy Clifford    male
# 205         0       3                    Mr. Karl Alfred Backstrom    male
# 289         1       1       Mrs. Dickinson H (Helen Walton) Bishop  female
# 2           1       3                        Miss. Laina Heikkinen  female
#
#       Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 522  40.5                        0                        0   7.7500
# ...

# %%
titanic_train['Sex'].value_counts()/titanic_train.shape[0]
# Out:
# Sex
# male      0.645998
# female    0.354002
# Name: count, dtype: float64

# %%
titanic_train['Fare']/titanic_train['Age']
# Out:
# 0      0.329545
# 1      1.875876
# 2      0.304808
# 3      1.517143
# 4      0.230000
#          ...
# 882    0.481481
# 883    1.578947
# 884    3.350000
# 885    1.153846
# 886    0.242188
# Length: 887, dtype: float64

# %%
titanic_train['Name'] + ' ' + titanic_train['Age'].astype(str)
# Out:
# 0                            Mr. Owen Harris Braund 22.0
# 1      Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                             Miss. Laina Heikkinen 26.0
# 3       Mrs. Jacques Heath (Lily May Peel) Futrelle 35.0
# 4                           Mr. William Henry Allen 35.0
#                              ...
# 882                            Rev. Juozas Montvila 27.0
# 883                     Miss. Margaret Edith Graham 19.0
# 884                   Miss. Catherine Helen Johnston 7.0
# 885                            Mr. Karl Howell Behr 26.0
# 886                              Mr. Patrick Dooley 32.0
# Length: 887, dtype: object

# %%
titanic_train[['Survived','Age','Sex']]
# Out:
#      Survived   Age     Sex
# 0           0  22.0    male
# 1           1  38.0  female
# 2           1  26.0  female
# 3           1  35.0  female
# 4           0  35.0    male
# ..        ...   ...     ...
# 882         0  27.0    male
# 883         1  19.0  female
# 884         0   7.0  female
# 885         1  26.0    male
# 886         0  32.0    male
#
# [887 rows x 3 columns]

# %%
titanic_train.loc[235]
# Out:
# Survived                                  0
# Pclass                                    2
# Name                       Mr. Stephen Hold
# Sex                                    male
# Age                                    44.0
# Siblings/Spouses Aboard                   1
# Parents/Children Aboard                   0
# Fare                                   26.0
# Name: 235, dtype: object

# %%
titanic_train.loc[titanic_train['Age']<20]
# Out:
#      Survived  Pclass                                 Name     Sex   Age  \
# 7           0       3        Master. Gosta Leonard Palsson    male   2.0
# 9           1       2   Mrs. Nicholas (Adele Achem) Nasser  female  14.0
# 10          1       3       Miss. Marguerite Rut Sandstrom  female   4.0
# 14          0       3  Miss. Hulda Amanda Adolfina Vestrom  female  14.0
# 16          0       3                  Master. Eugene Rice    male   2.0
# ..        ...     ...                                  ...     ...   ...
# 865         1       3       Master. Harold Theodor Johnson    male   4.0
# 871         1       3             Miss. Adele Kiamie Najib  female  15.0
# 873         0       3                  Mr. Nedelio Petroff    male  19.0
# 883         1       1          Miss. Margaret Edith Graham  female  19.0
# 884         0       3       Miss. Catherine Helen Johnston  female   7.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
titanic_train.loc[titanic_train['Age'].isin([30, 20])]
# Out:
#      Survived  Pclass                                               Name  \
# 12          0       3                      Mr. William Henry Saundercock
# 44          0       3                            Mr. William John Rogers
# 45          0       3                                   Mr. Denis Lennon
# 78          1       3                            Miss. Elizabeth Dowdell
# 86          0       3                       Mr. Selman Francis Slocovski
# 90          0       3                          Mr. Paul Edvin Andreasson
# 112         0       3                             Miss. Katriina Jussila
# 130         0       3                      Mr. Domingos Fernandeo Coelho
# 156         0       3                                     Mr. Harry Corn
# 177         0       2                                  Mr. Reginald Hale
# 212         0       2                         Mr. Hans Kristensen Givard
# 218         0       2                                  Mr. Walter Harris
# ...

# %%
titanic_train.groupby(['Sex', 'Survived']).agg({
    'Fare' : 'mean',
    'Age' : 'min'
    }).reset_index()
# Out:
#       Sex  Survived       Fare   Age
# 0  female         0  23.024385  2.00
# 1  female         1  51.938573  0.75
# 2    male         0  22.066170  1.00
# 3    male         1  40.821484  0.42
